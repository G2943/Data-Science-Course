# %%
a = "vaibhav"

# %%
b = 30

# %%
print("My name is {} my age is {}".format(a,b))
# Out:
# My name is vaibhav my age is 30

# %%
print(f"My name is {a} my age is {b}")
# Out:
# My name is vaibhav my age is 30

# %%
print(f"{"Python":<10}")
print(f"{"Python":>10}")
print(f"{"Python":^10}")
# Out:
# Python
#     Python
#   Python
