# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
s = {3, 4, 6}

# %%
type(s)
# Out:
# set

# %%
# Dictionary with key-value pairs
student = {
    "name": "Alice",
    "age": 25,
    "grade": "A"
}

# %%
student.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 student.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
type(student)_
# Out:
# dict

# %%
student["name"]
# Out:
# 'Alice'

# %%
print(student["age"])
# Out:
# 25

# %%
print(student["age"]=55)
# Out:
#   Cell In[10], line 1
#     print(student["age"]=55)
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
student["age"]=55

# %%
print(student["age"])
# Out:
# 55

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 55), ('grade', 'A')])

# %%
student.update({"name":"Brewis"})

# %%
student["name"]
# Out:
# 'Brewis'

# %%
student.values()
# Out:
# dict_values(['Brewis', 55, 'A'])

# %%
student.update("name":"Rutu", "lang":"Eng")
# Out:
#   Cell In[18], line 1
#     student.update("name":"Rutu", "lang":"Eng")
#                          ^
# SyntaxError: invalid syntax

# %%
student.update({"name":"Rutu", "lang":"Eng"})

# %%
student
# Out:
# {'name': 'Rutu', 'age': 55, 'grade': 'A', 'lang': 'Eng'}

# %%
student.pop("lang")
# Out:
# 'Eng'

# %%
student
# Out:
# {'name': 'Rutu', 'age': 55, 'grade': 'A'}

# %%
student.setdefault("grade","B")
# Out:
# 'A'

# %%
student.update({"lang":"Eng"})

# %%
student
# Out:
# {'name': 'Rutu', 'age': 55, 'grade': 'A', 'lang': 'Eng'}

# %%
student.update({"lang":""})

# %%
student.setdefault("lang","Mar")
# Out:
# ''
