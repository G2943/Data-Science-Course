# %%
s = {2, 4, 4, 55, 63, 665}

# %%
s
# Out:
# {2, 4, 55, 63, 665}

# %%
s.update([2,34,556])

# %%
s
# Out:
# {2, 4, 34, 55, 63, 556, 665}

# %%
s.remove(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 s.remove(3)
#
# KeyError: 3

# %%
s.remove(665)

# %%
s
# Out:
# {2, 4, 34, 55, 63, 556}

# %%
s.discard(3)

# %%
s.discard(55)

# %%
s
# Out:
# {2, 4, 34, 63, 556}

# %%
ss = s.copy()

# %%
ss
# Out:
# {2, 4, 34, 63, 556}

# %%
ss.pop()
# Out:
# 2

# %%
ss
# Out:
# {4, 34, 63, 556}

# %%
b = {3, 4, 6,33}
bb = {4, 5, 66, 3}

# %%
b.union(bb)
# Out:
# {3, 4, 5, 6, 33, 66}

# %%
b
# Out:
# {3, 4, 6, 33}

# %%
bb
# Out:
# {3, 4, 5, 66}

# %%
b.intersection(bb)
# Out:
# {3, 4}
