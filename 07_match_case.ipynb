# %%
code = 44;
match code:
    case 200:
        print("Response OK")
    case 400:
        print("Bad Response")
    case 404:
        print("Page Not Found")
    case _:
        print("Nothing matched")
print("Out of program")
# Out:
# Nothing matched
# Out of program
