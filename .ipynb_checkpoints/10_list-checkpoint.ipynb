# %%
l = [1, 2, 44, 33, 23]

# %%
l[3]
# Out:
# 33

# %%
l[1] = 88 #lists are mutable

# %%
l
# Out:
# [1, 88, 44, 33, 23]

# %%
l
# Out:
# [1, 88, 44, 33, 23]

# %%
l.append(77)

# %%
l
# Out:
# [1, 88, 44, 33, 23, 77]

# %%
t = [2, 5, True, False, [5, 33]]

# %%
t
# Out:
# [2, 5, True, False, [5, 33]]

# %%
t[4][0]
# Out:
# 5

# %%
t[4][1]
# Out:
# 33

# %%
list1 = [4, 6, 2]

# %%
list2 = [6, 2, 66]

# %%
list1 + list2
# Out:
# [4, 6, 2, 6, 2, 66]

# %%
if 2 in list1:
    print("Yes")
# Out:
# Yes

# %%
33 in list1
# Out:
# False

# %%
#packing tuple

# %%
person = ( "Amit", 45, "engineer")

# %%
#Unpacking tuple

# %%
name, age, profession = person

# %%
name
# Out:
# 'Amit'

# %%
age
# Out:
# 45

# %%
profession
# Out:
# 'engineer'
