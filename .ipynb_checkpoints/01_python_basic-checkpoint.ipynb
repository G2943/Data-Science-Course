# %%
a = 2

# %%
b = 4

# %%
a + b
# Out:
# 6

# %%
name = "Vaibhav"

# %%
print("Hello World") # This will print Hello World
# Out:
# Hello World

# %%
type(name)
# Out:
# str

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
p = "333"

# %%
q = " 555"

# %%
p + q
# Out:
# '333 555'

# %%
int(p) + int (q) # Typecasting
# Out:
# 888
