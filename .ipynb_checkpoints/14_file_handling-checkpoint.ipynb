# %%
f = open("text.txt",'r')

# %%
f.read()
# Out:
# 'This is just random string'

# %%
s = "This is just random string"

# %%
f.close()

# %%
f = open("me.txt","w")

# %%
f.write(s)
# Out:
# 26

# %%
f.close()
