# %%
name = "Vaibhav"

# %%
name
# Out:
# 'Vaibhav'

# %%
name.upper()
# Out:
# 'VAIBHAV'

# %%
name.lower()
# Out:
# 'vaibhav'

# %%
name[1,-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 name[1,-1]
#
# TypeError: string indices must be integers, not 'tuple'

# %%
name[1:-1]
# Out:
# 'aibha'
