# %%
l = [3, 5, 6, 3, 66]

# %%
for item in l:
    print(item)
# Out:
# 3
# 5
# 6
# 3
# 66

# %%
for i in range(5, 10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
i = 0
while i<5:
    print(i)
    i = i + 1
# Out:
# 0
# 1
# 2
# 3
# 4
